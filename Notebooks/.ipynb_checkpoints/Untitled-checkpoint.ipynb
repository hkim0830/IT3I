# %%
# Make sure you have some data
import pandas as pd

precomputed_counts = pd.DataFrame(
    {'Strongly disagree': {'Would Use Again': 2.0, 'Q2': 2.0},
     'Disagree': {'Would Use Again': 1.0, 'Q2': 0.0},
     'Neither agree nor disagree': {'Would Use Again': 3.0, 'Q2': 2.0},
     'Agree': {'Would Use Again': 3.0, 'Q2': 4.0},
     'Strongly agree': {'Would Use Again': 1.0, 'Q2': 2.0}}
)
precomputed_counts
# Now plot it!
import plot_likert

plot_likert.plot_counts(precomputed_counts, plot_likert.scales.agree);
