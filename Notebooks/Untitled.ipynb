# %%
# Make sure you have some data
import pandas as pd

precomputed_counts = pd.DataFrame(
    {'Strongly disagree': {'Would Use Again': 0, 'Found Helpful': 0, 'Useful': 0},
     'Disagree': {'Would Use Again': 0, 'Found Helpful': 0.0},
     'Neither agree nor disagree': {'Would Use Again': 0, 'Found Helpful': 2.0, 'Useful': 1},
     'Agree': {'Would Use Again': 3.0, 'Found Helpful': 3.0, 'Useful': 4},
     'Strongly agree': {'Would Use Again': 4.0, 'Found Helpful': 2.0, 'Useful': 2}}
)
precomputed_counts
# Now plot it!
import plot_likert

plot_likert.plot_counts(precomputed_counts, plot_likert.scales.agree);
